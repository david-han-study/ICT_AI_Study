# %%
# Class


# 실습 1
# 딕셔너리로 만들기
students = [
    {'name': '윤인성', 'korean': 80, 'math': 60, 'english': 88, 'science': 92 },
    {'name': '김철수', 'korean': 90, 'math': 70, 'english': 88, 'science': 93 },
    {'name': '박영수', 'korean': 79, 'math': 80, 'english': 78, 'science': 94 },
    {'name': '윤아린', 'korean': 90, 'math': 90, 'english': 68, 'science': 95 },
    {'name': '김영희', 'korean': 88, 'math': 90, 'english': 58, 'science': 96 },
    {'name': '이연희', 'korean': 59, 'math': 90, 'english': 78, 'science': 97 },
]

print('이름\t총점\t평균')

for s in students:
    sum = s['korean'] + s['math'] + s['english'] + s['science']
    average = sum / 4
    print(s['name'], sum, average, sep='\t')
# Out:
# 이름	총점	평균
# 윤인성	320	80.0
# 김철수	341	85.25
# 박영수	331	82.75
# 윤아린	343	85.75
# 김영희	332	83.0
# 이연희	324	81.0
