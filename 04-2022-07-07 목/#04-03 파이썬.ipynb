# %%
# 튜플
# - 리스트와 유사한 자료형
# - 한번 결정된 요소는 바꿀 수 없음

a = (1, 2, 3, 4, 5)

# a[2] = 3 # error 튜플은 바꿀 수 없음

# %%
# 괄호 없는 튜플
[a, b] = [10, 20]
(c, d) = (10, 20)

t = 10, 20 , 30
e, f, g = 10, 20, 30

print(a)
print(b)
print(c)
print(d)
print(t)
print(e)
print(f)
print(g)
# Out:
# 10
# 20
# 10
# 20
# (10, 20, 30)
# 10
# 20
# 30

# %%
a, b = 10, 20
print(a, b)

# 값을 교환
a, b = b, a
print(a, b)
# Out:
# 10 20
# 20 10

# %%
# 여러 값 리턴하기
def test():
  return (10, 20)

def test2():
  return 10, 20

a, b = test()
c, d = test2()

print(a, b)
print(c, d)
# Out:
# 10 20
# 10 20

# %%
# 람다 lambda
# 기능을 매개변수로 전달하는 코드를 더 효율적으로 작성
# 함수의 매개변수로 함수 전달하기

def call_10_times(func) :
  for i in range(10):
    func()

def print_hello():
  print('안녕')

call_10_times(print_hello)
# Out:
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕

# %%
# filter(), map()
# - 함수를 매개변수로 전달하는 대표적인 표준함수

# map(함수, 리스트)
# filter(함수, 리스트)

def power(item):
  return item * item

def under_3(item):
  return item < 3

list_input_a = [1, 2, 3, 4, 5]
output_a = map(power, list_input_a)
print(output_a)
print(list(output_a))
print()

output_b = filter(under_3, list_input_a)
print(output_b)
print(list(output_b))
# Out:
# ...
# [1, 4, 9, 16, 25]
#
# ...
# [1, 2]

# %%
# 람다
# 간단한 함수를 쉽게 선언하는 방법

# lambda 매개변수 : 리턴값

# def power(x):
#   return x * x
power2 = lambda x: x * x
under_3_2 = lambda x: x < 3

list_input_b = [1, 2, 3, 4, 5, 6]
output_c = map(power2, list_input_b)
output_d = filter(under_3_2, list_input_b)

print(output_c)
print(list(output_c))
print(output_d)
print(list(output_d))
# Out:
# ...
# [1, 4, 9, 16, 25, 36]
# ...
# [1, 2]

# %%
# 인라인 람다
# - 함수의 매개변수에 람다 곧바로 넣을 수 있음

output_e = map(lambda x: x * x, list_input_b)

print(output_e)
print(list(output_e))
# Out:
# ...
# [1, 4, 9, 16, 25, 36]

# %%
# 매개 변수가 여러개인 람다
sum = lambda x, y: x + y
print(sum(10, 20))
# Out:
# 30
